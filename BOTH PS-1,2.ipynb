# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as pl
import seaborn as sns

# %%
import pandas as pd
df1 = pd.read_csv("Play Store Data part 1.csv")#reading the play store variable 1
df2 = pd.read_csv("play store data part 2.csv")#reading the play store variable 2

# %%
df=pd.merge(df1,df2)
df    #here using df as a varible to print the merged version of df1 and df2
df.head()  #head() function prints only the top 5 values
# Out:
#                    App        Category  Rating Reviews Size  Installs  Type  \
# 0  Coloring book moana  ART_AND_DESIGN     3.9     967  14M  500,000+  Free
# 1  Coloring book moana  ART_AND_DESIGN     3.9     967  14M  500,000+  Free
# 2  Coloring book moana  ART_AND_DESIGN     3.9     967  14M  500,000+  Free
# 3  Coloring book moana  ART_AND_DESIGN     3.9     967  14M  500,000+  Free
# 4  Coloring book moana  ART_AND_DESIGN     3.9     967  14M  500,000+  Free
#
#   Price Content Rating                     Genres      Last Updated  \
# 0     0       Everyone  Art & Design;Pretend Play  January 15, 2018
# 1     0       Everyone  Art & Design;Pretend Play  January 15, 2018
# 2     0       Everyone  Art & Design;Pretend Play  January 15, 2018
# 3     0       Everyone  Art & Design;Pretend Play  January 15, 2018
# 4     0       Everyone  Art & Design;Pretend Play  January 15, 2018
#
#   Current Ver   Android Ver  \
# 0       2.0.0  4.0.3 and up
# 1       2.0.0  4.0.3 and up
# ...

# %%
df.shape#shape is for printing the number of rows and columns
# Out:
# (122662, 17)

# %%
df.describe()  #describe function describes the complete data set in means of different varibales like minimum ,maximum ,etc
# Out:
#               Rating  Sentiment_Polarity  Sentiment_Subjectivity
# count  122622.000000        72615.000000            72615.000000
# mean        4.322405            0.157320                0.494162
# std         0.284766            0.332652                0.240144
# min         2.500000           -1.000000                0.000000
# 25%         4.200000            0.000000                0.380000
# 50%         4.400000            0.129167                0.509740
# 75%         4.500000            0.356250                0.633333
# max         4.900000            1.000000                1.000000

# %%
df.info() #info() function is used to display the columns with thier data types
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 122662 entries, 0 to 122661
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   App                     122662 non-null  object
#  1   Category                122662 non-null  object
#  2   Rating                  122622 non-null  float64
#  3   Reviews                 122662 non-null  object
#  4   Size                    122662 non-null  object
#  5   Installs                122662 non-null  object
#  6   Type                    122662 non-null  object
#  7   Price                   122662 non-null  object
#  8   Content Rating          122662 non-null  object
#  9   Genres                  122662 non-null  object
#  10  Last Updated            122662 non-null  object
#  11  Current Ver             122662 non-null  object
#  12  Android Ver             122662 non-null  object
#  13  Translated_Review       72605 non-null   object
# ...

# %%
df.isnull()  #is null() function prints true if the value is 0 and false if they are not zero
# Out:
#           App  Category  Rating  Reviews   Size  Installs   Type  Price  \
# 0       False     False   False    False  False     False  False  False
# 1       False     False   False    False  False     False  False  False
# 2       False     False   False    False  False     False  False  False
# 3       False     False   False    False  False     False  False  False
# 4       False     False   False    False  False     False  False  False
# ...       ...       ...     ...      ...    ...       ...    ...    ...
# 122657  False     False   False    False  False     False  False  False
# 122658  False     False   False    False  False     False  False  False
# 122659  False     False   False    False  False     False  False  False
# 122660  False     False   False    False  False     False  False  False
# 122661  False     False   False    False  False     False  False  False
#
#         Content Rating  Genres  Last Updated  Current Ver  Android Ver  \
# ...

# %%
df.isnull().sum()#here sum() is used to total the nulll values in the data set
# Out:
# App                           0
# Category                      0
# Rating                       40
# Reviews                       0
# Size                          0
# Installs                      0
# Type                          0
# Price                         0
# Content Rating                0
# Genres                        0
# Last Updated                  0
# Current Ver                   0
# Android Ver                   0
# Translated_Review         50057
# Sentiment                 50047
# Sentiment_Polarity        50047
# Sentiment_Subjectivity    50047
# dtype: int64

# %%
 df.dropna(axis=0,how='any') #dropna tries to remove the null values
# Out:
#                                  App        Category  Rating Reviews  \
# 0                Coloring book moana  ART_AND_DESIGN     3.9     967
# 1                Coloring book moana  ART_AND_DESIGN     3.9     967
# 2                Coloring book moana  ART_AND_DESIGN     3.9     967
# 4                Coloring book moana  ART_AND_DESIGN     3.9     967
# 5                Coloring book moana  ART_AND_DESIGN     3.9     967
# ...                              ...             ...     ...     ...
# 122646  A+ Gallery - Photos & Videos     PHOTOGRAPHY     4.5  223941
# 122652  A+ Gallery - Photos & Videos     PHOTOGRAPHY     4.5  223941
# 122659  A+ Gallery - Photos & Videos     PHOTOGRAPHY     4.5  223941
# 122660  A+ Gallery - Photos & Videos     PHOTOGRAPHY     4.5  223941
# 122661  A+ Gallery - Photos & Videos     PHOTOGRAPHY     4.5  223941
#
#                       Size     Installs  Type Price Content Rating  \
# 0                      14M     500,000+  Free     0       Everyone
# ...

# %%
df.memory_usage(deep=True)  #memory_usage gives us the total amount of memory that is consumed by each and every variables
# Out:
# Index                       981296
# App                       10229688
# Category                   8079223
# Rating                      981296
# Reviews                    7695204
# Size                       8084154
# Installs                   8287274
# Type                       7482382
# Price                      7121132
# Content Rating             7950764
# Genres                     8247142
# Last Updated               8639838
# Current Ver                8184961
# Android Ver                8528118
# Translated_Review         15405217
# Sentiment                  6313193
# Sentiment_Polarity          981296
# Sentiment_Subjectivity      981296
# dtype: int64

# %%
df['Category']=df.Category.astype('ART_AND_DESIGN')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2724/2979919918.py in <module>
# ----> 1 df['Category']=df.Category.astype('ART_AND_DESIGN')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     416
#     417     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 418         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     419
# ...

# %%
df.loc[0:4,['App','Size','Type']]  #this shortens the data set and gives us the only wanted data 
#and if we want from 10 to 15 we can just give like [10:15]
# Out:
#                    App Size  Type
# 0  Coloring book moana  14M  Free
# 1  Coloring book moana  14M  Free
# 2  Coloring book moana  14M  Free
# 3  Coloring book moana  14M  Free
# 4  Coloring book moana  14M  Free

# %%
df['Category'].value_counts() #here we areaccessing the sepertae categorical type and
#printing their totals
# Out:
# GAME                   28360
# FAMILY                  9947
# SPORTS                  8840
# HEALTH_AND_FITNESS      6562
# PRODUCTIVITY            5780
# DATING                  5756
# PHOTOGRAPHY             5660
# COMMUNICATION           4460
# TRAVEL_AND_LOCAL        4380
# SHOPPING                4320
# ENTERTAINMENT           4260
# EDUCATION               3480
# MEDICAL                 3394
# TOOLS                   3239
# NEWS_AND_MAGAZINES      3200
# BUSINESS                3160
# FINANCE                 3080
# PERSONALIZATION         2200
# LIFESTYLE               2103
# SOCIAL                  1800
# FOOD_AND_DRINK          1471
# BOOKS_AND_REFERENCE     1372
# HOUSE_AND_HOME          1356
# AUTO_AND_VEHICLES        603
# BEAUTY                   591
# ART_AND_DESIGN           548
# LIBRARIES_AND_DEMO       520
# VIDEO_PLAYERS            500
# PARENTING                440
# MAPS_AND_NAVIGATION      440
# EVENTS                   280
# WEATHER                  280
# ...

# %%
# df = DataFrame({'text': ['foo', 'bar'],
#                  'number': [1, 2]})
# df.style.set_properties(**{'text-align': 'right'})

# %%
df.drop_duplicates(inplace=True)
df  #duplicates rows are removed using drop _duplicates function
# Out:
#                                  App        Category  Rating Reviews  \
# 0                Coloring book moana  ART_AND_DESIGN     3.9     967
# 1                Coloring book moana  ART_AND_DESIGN     3.9     967
# 2                Coloring book moana  ART_AND_DESIGN     3.9     967
# 3                Coloring book moana  ART_AND_DESIGN     3.9     967
# 4                Coloring book moana  ART_AND_DESIGN     3.9     967
# ...                              ...             ...     ...     ...
# 122646  A+ Gallery - Photos & Videos     PHOTOGRAPHY     4.5  223941
# 122652  A+ Gallery - Photos & Videos     PHOTOGRAPHY     4.5  223941
# 122659  A+ Gallery - Photos & Videos     PHOTOGRAPHY     4.5  223941
# 122660  A+ Gallery - Photos & Videos     PHOTOGRAPHY     4.5  223941
# 122661  A+ Gallery - Photos & Videos     PHOTOGRAPHY     4.5  223941
#
#                       Size     Installs  Type Price Content Rating  \
# 0                      14M     500,000+  Free     0       Everyone
# ...

# %%
df['Rating']==4.5 #checking that if the rating variables values are all equal to 4.5 or not ,
#if it is equal then it prints TRUE or else FALSE
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 122646     True
# 122652     True
# 122659     True
# 122660     True
# 122661     True
# Name: Rating, Length: 41661, dtype: bool

# %%
df = pd.DataFrame(, columns = [ 'Rating', 'Size'],
                  index = ['a', 'b', 'c', 'd', 'e', 'f'])
# Out:
#   File "C:\Users\ROHITH\AppData\Local\Temp/ipykernel_2724/535810481.py", line 1
#     df = pd.DataFrame(, columns = [ 'Rating', 'Size'],
#                       ^
# SyntaxError: invalid syntax

# %%
df['App'].unique
# Out:
# <bound method Series.unique of 0                  Coloring book moana
# 1                  Coloring book moana
# 2                  Coloring book moana
# 3                  Coloring book moana
# 4                  Coloring book moana
#                       ...
# 122646    A+ Gallery - Photos & Videos
# 122652    A+ Gallery - Photos & Videos
# 122659    A+ Gallery - Photos & Videos
# 122660    A+ Gallery - Photos & Videos
# 122661    A+ Gallery - Photos & Videos
# Name: App, Length: 41661, dtype: object>

# %%
df['Price'].unique
# Out:
# <bound method Series.unique of 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 122646    0
# 122652    0
# 122659    0
# 122660    0
# 122661    0
# Name: Price, Length: 41661, dtype: object>

# %%
df.dtypes
# Out:
# App                        object
# Category                   object
# Rating                    float64
# Reviews                    object
# Size                       object
# Installs                   object
# Type                       object
# Price                      object
# Content Rating             object
# Genres                     object
# Last Updated               object
# Current Ver                object
# Android Ver                object
# Translated_Review          object
# Sentiment                  object
# Sentiment_Polarity        float64
# Sentiment_Subjectivity    float64
# dtype: object

# %%
df[df['Rating']==4.5].head() #gives the 1st five app names where rating is equals to 4.5
# Out:
#                            App        Category  Rating Reviews Size  Installs  \
# 416  Anime Manga Coloring Book  ART_AND_DESIGN     4.5    5035  11M  100,000+
# 417  Anime Manga Coloring Book  ART_AND_DESIGN     4.5    5035  11M  100,000+
# 418  Anime Manga Coloring Book  ART_AND_DESIGN     4.5    5035  11M  100,000+
# 420  Anime Manga Coloring Book  ART_AND_DESIGN     4.5    5035  11M  100,000+
# 422  Anime Manga Coloring Book  ART_AND_DESIGN     4.5    5035  11M  100,000+
#
#      Type Price Content Rating        Genres   Last Updated Current Ver  \
# 416  Free     0       Everyone  Art & Design  July 19, 2018        2.20
# 417  Free     0       Everyone  Art & Design  July 19, 2018        2.20
# 418  Free     0       Everyone  Art & Design  July 19, 2018        2.20
# 420  Free     0       Everyone  Art & Design  July 19, 2018        2.20
# 422  Free     0       Everyone  Art & Design  July 19, 2018        2.20
#
# ...

# %%
df.corr()
# Out:
#                           Rating  Sentiment_Polarity  Sentiment_Subjectivity
# Rating                  1.000000            0.075309                0.071372
# Sentiment_Polarity      0.075309            1.000000                0.244923
# Sentiment_Subjectivity  0.071372            0.244923                1.000000

# %%
df.tail() #tail() is used for getting the last 5rows
# Out:
#                                  App     Category  Rating Reviews  \
# 122646  A+ Gallery - Photos & Videos  PHOTOGRAPHY     4.5  223941
# 122652  A+ Gallery - Photos & Videos  PHOTOGRAPHY     4.5  223941
# 122659  A+ Gallery - Photos & Videos  PHOTOGRAPHY     4.5  223941
# 122660  A+ Gallery - Photos & Videos  PHOTOGRAPHY     4.5  223941
# 122661  A+ Gallery - Photos & Videos  PHOTOGRAPHY     4.5  223941
#
#                       Size     Installs  Type Price Content Rating  \
# 122646  Varies with device  10,000,000+  Free     0       Everyone
# 122652  Varies with device  10,000,000+  Free     0       Everyone
# 122659  Varies with device  10,000,000+  Free     0       Everyone
# 122660  Varies with device  10,000,000+  Free     0       Everyone
# 122661  Varies with device  10,000,000+  Free     0       Everyone
#
#              Genres    Last Updated         Current Ver         Android Ver  \
# 122646  Photography  August 6, 2018  Varies with device  Varies with device
# ...

# %%
 df.columns #it gives only the names of the columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver', 'Translated_Review', 'Sentiment', 'Sentiment_Polarity',
#        'Sentiment_Subjectivity'],
#       dtype='object')

# %%
df.dtypes #gives the data types of the variables
# Out:
# App                        object
# Category                   object
# Rating                    float64
# Reviews                    object
# Size                       object
# Installs                   object
# Type                       object
# Price                      object
# Content Rating             object
# Genres                     object
# Last Updated               object
# Current Ver                object
# Android Ver                object
# Translated_Review          object
# Sentiment                  object
# Sentiment_Polarity        float64
# Sentiment_Subjectivity    float64
# dtype: object

# %%
sns.heatmap(df.isnull())   #heatmap is used to visualize the data bcoz human brain can underrstand better the visualization than the number or text data
# Out:
# <AxesSubplot:>

# %%
df.dropna(inplace=True,axis=0)    #dropna function removes the rows and columns that contains NULL values

# %%
df.isnull().sum()
# Out:
# App                       0
# Category                  0
# Rating                    0
# Reviews                   0
# Size                      0
# Installs                  0
# Type                      0
# Price                     0
# Content Rating            0
# Genres                    0
# Last Updated              0
# Current Ver               0
# Android Ver               0
# Translated_Review         0
# Sentiment                 0
# Sentiment_Polarity        0
# Sentiment_Subjectivity    0
# dtype: int64

# %%
df['Type'].value_counts()
# Out:
# Free    71784
# Paid      782
# Name: Type, dtype: int64

# %%
df['Sentiment_Polarity'].value_counts()  #gives the o/p sorted in the values
# Out:
#  0.000000    8272
#  0.500000    2495
#  0.700000    1483
#  1.000000    1459
#  0.300000    1044
#              ...
#  0.267424       1
#  0.250391       1
#  0.460417       1
# -0.155357       1
#  0.509821       1
# Name: Sentiment_Polarity, Length: 5295, dtype: int64

# %%
df['Price'].unique() #unique function gives the values of the price
# Out:
# array(['0', '$4.99', '$6.99', '$3.99', '$11.99', '$9.99', '$29.99',
#        '$2.49', '$0.99'], dtype=object)

# %%
df['Price'].nunique() #nunique function gives the totsl number of price values
# Out:
# 9

# %%
# df.groupby('Genres')['Last Updated'].mean().reset_index()

# %%
##Analyse embarked columns

# %%
f,ax=pl.subplots(1,2,figsize=(18,8))

df['Price'].value_counts().plot.pie(axis=ax[0])
pl.show()

# %%
# df.pivot_tablet('')

# %%
cat_sorted_installs = cat_score.sort_values(by='Installs', ascending=False)
plt.figure(figsize=(40, 20))
sns.barplot(x=cat_sorted_installs.index, y=cat_sorted_installs['Installs'], palette='mako').set(xlabel='Category', ylabel='Installs', title='Category vs. Installs (sorted)')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11132/1479454361.py in <module>
# ----> 1 cat_sorted_installs = cat_score.sort_values(by='Installs', ascending=False)
#       2 plt.figure(figsize=(40, 20))
#       3 sns.barplot(x=cat_sorted_installs.index, y=cat_sorted_installs['Installs'], palette='mako').set(xlabel='Category', ylabel='Installs', title='Category vs. Installs (sorted)')
#
# NameError: name 'cat_score' is not defined
