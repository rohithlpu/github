# %% [markdown]
# ### PLAY STORE DATA SET:
# Introduction
#
# · Data Preparation and Cleaning
#
# · Exploratory Analysis and Visualization
#
#   ∘ Let’s have a look at the distribution of the ratings of the data frame.
#
#   ∘ Let’s plot a visualization graph to view what portion of the apps in the play store are paid and free.
#
#   ∘ Which category App’s have the most number of installs?
#
# · Asking and Answering Questions
#
#   ∘ What are the Top 10 installed apps in any category?
#
#   ∘ Which are the top 10 expensive Apps in the play store?
#
#   ∘ Which are the Apps with the highest number of reviews?
#
#   ∘ What are the count of Apps in different genres?
#
#   ∘ Which are the apps that have made the highest-earning?
#
# · Inferences and Conclusion
#
# · References

# %% [markdown]
# ## introduction:
#
# There are more than 3.04 million apps found on Google Play Store. With this project/article I will take you through a journey of analyzing various apps found on the play store with the help of different python libraries.
#
# Dataset: The dataset is been taken from Kaggle, which can be found here Link
#
# It consists of 17 columns:- App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, and Android Ver with 122662 Rows.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
import plotly
import plotly.express as px
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Above lines of code are for importing packages

# %%
df1=pd.read_csv("Play Store Data part 1.csv")
df2=pd.read_csv("play store data part 2.csv")

# %% [markdown]
# Here Im importing two data sets together and below im merging it to make them together

# %%
#merge function is used to merge the two data sets into a single data set
df=pd.merge(df1,df2)

# %%
df.head()
# Out:
#                    App        Category  Rating Reviews Size  Installs  Type  \
# 0  Coloring book moana  ART_AND_DESIGN     3.9     967  14M  500,000+  Free
# 1  Coloring book moana  ART_AND_DESIGN     3.9     967  14M  500,000+  Free
# 2  Coloring book moana  ART_AND_DESIGN     3.9     967  14M  500,000+  Free
# 3  Coloring book moana  ART_AND_DESIGN     3.9     967  14M  500,000+  Free
# 4  Coloring book moana  ART_AND_DESIGN     3.9     967  14M  500,000+  Free
#
#   Price Content Rating                     Genres      Last Updated  \
# 0     0       Everyone  Art & Design;Pretend Play  January 15, 2018
# 1     0       Everyone  Art & Design;Pretend Play  January 15, 2018
# 2     0       Everyone  Art & Design;Pretend Play  January 15, 2018
# 3     0       Everyone  Art & Design;Pretend Play  January 15, 2018
# 4     0       Everyone  Art & Design;Pretend Play  January 15, 2018
#
#   Current Ver   Android Ver  \
# 0       2.0.0  4.0.3 and up
# 1       2.0.0  4.0.3 and up
# ...

# %% [markdown]
# To know if there is any missing value or Nan value in the dataset, we can use the isnull() function.

# %%
df.isnull().sum()
# Out:
# App                           0
# Category                      0
# Rating                       40
# Reviews                       0
# Size                          0
# Installs                      0
# Type                          0
# Price                         0
# Content Rating                0
# Genres                        0
# Last Updated                  0
# Current Ver                   0
# Android Ver                   0
# Translated_Review         50057
# Sentiment                 50047
# Sentiment_Polarity        50047
# Sentiment_Subjectivity    50047
# dtype: int64

# %%
def printinfo():
    temp = pd.DataFrame(index=df.columns)
    temp['data_type'] = df.dtypes
    temp['unique_count'] = df.nunique()
    return temp

# %%
printinfo()
# Out:
#                        data_type  unique_count
# App                       object          1020
# Category                  object            33
# Rating                   float64            23
# Reviews                   object          1330
# Size                      object           178
# Installs                  object            13
# Type                      object             2
# Price                     object            14
# Content Rating            object             5
# Genres                    object            73
# Last Updated              object           299
# Current Ver               object           598
# Android Ver               object            25
# Translated_Review         object         26682
# Sentiment                 object             3
# Sentiment_Polarity       float64          5295
# Sentiment_Subjectivity   float64          4382

# %% [markdown]
# By using the above function we are checking the data types and total count of a particular variable

# %% [markdown]
# To see only the column name we can use the following function:

# %%
df[df.Type.isnull()]
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver, Translated_Review, Sentiment, Sentiment_Polarity, Sentiment_Subjectivity]
# Index: []

# %% [markdown]
# We can fill the empty spaces with the word FREE:

# %%
df['Type'].fillna("Free", inplace = True)
df
# Out:
#                                  App        Category  Rating Reviews  \
# 0                Coloring book moana  ART_AND_DESIGN     3.9     967
# 1                Coloring book moana  ART_AND_DESIGN     3.9     967
# 2                Coloring book moana  ART_AND_DESIGN     3.9     967
# 3                Coloring book moana  ART_AND_DESIGN     3.9     967
# 4                Coloring book moana  ART_AND_DESIGN     3.9     967
# ...                              ...             ...     ...     ...
# 122657  A+ Gallery - Photos & Videos     PHOTOGRAPHY     4.5  223941
# 122658  A+ Gallery - Photos & Videos     PHOTOGRAPHY     4.5  223941
# 122659  A+ Gallery - Photos & Videos     PHOTOGRAPHY     4.5  223941
# 122660  A+ Gallery - Photos & Videos     PHOTOGRAPHY     4.5  223941
# 122661  A+ Gallery - Photos & Videos     PHOTOGRAPHY     4.5  223941
#
#                       Size     Installs  Type Price Content Rating  \
# 0                      14M     500,000+  Free     0       Everyone
# ...

# %%
#To Print only the top 5values, use df.head() function:
df.head()
# Out:
#                    App        Category  Rating Reviews Size  Installs  Type  \
# 0  Coloring book moana  ART_AND_DESIGN     3.9     967  14M  500,000+  Free
# 1  Coloring book moana  ART_AND_DESIGN     3.9     967  14M  500,000+  Free
# 2  Coloring book moana  ART_AND_DESIGN     3.9     967  14M  500,000+  Free
# 3  Coloring book moana  ART_AND_DESIGN     3.9     967  14M  500,000+  Free
# 4  Coloring book moana  ART_AND_DESIGN     3.9     967  14M  500,000+  Free
#
#   Price Content Rating                     Genres      Last Updated  \
# 0     0       Everyone  Art & Design;Pretend Play  January 15, 2018
# 1     0       Everyone  Art & Design;Pretend Play  January 15, 2018
# 2     0       Everyone  Art & Design;Pretend Play  January 15, 2018
# 3     0       Everyone  Art & Design;Pretend Play  January 15, 2018
# 4     0       Everyone  Art & Design;Pretend Play  January 15, 2018
#
#   Current Ver   Android Ver  \
# 0       2.0.0  4.0.3 and up
# 1       2.0.0  4.0.3 and up
# ...

# %%
df.loc[10368:10377]
# Out:
#                                 App       Category  Rating Reviews  Size  \
# 10368  ExDialer - Dialer & Contacts  COMMUNICATION     4.2  125232  2.7M
# 10369  ExDialer - Dialer & Contacts  COMMUNICATION     4.2  125232  2.7M
# 10370  ExDialer - Dialer & Contacts  COMMUNICATION     4.2  125232  2.7M
# 10371  ExDialer - Dialer & Contacts  COMMUNICATION     4.2  125232  2.7M
# 10372  ExDialer - Dialer & Contacts  COMMUNICATION     4.2  125232  2.7M
# 10373  ExDialer - Dialer & Contacts  COMMUNICATION     4.2  125232  2.7M
# 10374  ExDialer - Dialer & Contacts  COMMUNICATION     4.2  125232  2.7M
# 10375  ExDialer - Dialer & Contacts  COMMUNICATION     4.2  125232  2.7M
# 10376  ExDialer - Dialer & Contacts  COMMUNICATION     4.2  125232  2.7M
# 10377  ExDialer - Dialer & Contacts  COMMUNICATION     4.2  125232  2.7M
#
#           Installs  Type Price Content Rating         Genres   Last Updated  \
# 10368  10,000,000+  Free     0       Everyone  Communication  March 5, 2017
# ...

# %% [markdown]
# Checking the mean, max , min values of the data set:

# %%
df.describe().T
# Out:
#           count      mean       std  min  25%  50%  75%  max
# Rating  41616.0  4.323928  0.286486  2.5  4.2  4.4  4.5  4.9

# %% [markdown]
# Checking the memory space of each:

# %%
df.memory_usage(deep=True)
# Out:
# Index                 333240
# App                  3516219
# Category             2748561
# Rating                333240
# Reviews              2607840
# Size                 2720951
# Installs             2808179
# Type                 2540955
# Price                2417624
# Content Rating       2696461
# Genres               2804581
# Last Updated         2932247
# Current Ver          2753898
# Android Ver          2891400
# Translated_Review    7218761
# dtype: int64

# %% [markdown]
# By using the above function we come to know the memory space consumed by each and it will help us to minimize if we need to

# %%
df['Category'].value_counts()
# Out:
# GAME                   9467
# FAMILY                 3669
# HEALTH_AND_FITNESS     1933
# TRAVEL_AND_LOCAL       1817
# TOOLS                  1721
# PRODUCTIVITY           1714
# SPORTS                 1656
# FINANCE                1629
# PHOTOGRAPHY            1594
# DATING                 1548
# MEDICAL                1351
# COMMUNICATION          1345
# PERSONALIZATION        1239
# SHOPPING               1025
# SOCIAL                 1000
# LIFESTYLE               970
# NEWS_AND_MAGAZINES      926
# ENTERTAINMENT           897
# BUSINESS                829
# EDUCATION               771
# BOOKS_AND_REFERENCE     736
# FOOD_AND_DRINK          683
# HOUSE_AND_HOME          526
# ART_AND_DESIGN          366
# LIBRARIES_AND_DEMO      342
# VIDEO_PLAYERS           335
# BEAUTY                  325
# AUTO_AND_VEHICLES       292
# PARENTING               267
# WEATHER                 233
# MAPS_AND_NAVIGATION     200
# EVENTS                  162
# COMICS                   87
# ...

# %% [markdown]
# *From above output we could check the most downloaded app by the people. From above observation we could see that GAMING apps are  downloaded, it means most of the childrens and adults are addicted to games.If u look at library apps and news apps it is very less compared to games and entertainment by which we can tell that most of the people are lead to addiction.
# *In 2019, the World Health Organization recognized “Gaming Disorder” as a mental health condition. It is officially added to the International Classification of Diseases, "ICD-11", in 2022.

# %%
# Copying the data set
df1 = df.copy()
df1
# Out:
#                                  App        Category  Rating Reviews  \
# 0                Coloring book moana  ART_AND_DESIGN     3.9     967
# 1                Coloring book moana  ART_AND_DESIGN     3.9     967
# 2                Coloring book moana  ART_AND_DESIGN     3.9     967
# 3                Coloring book moana  ART_AND_DESIGN     3.9     967
# 4                Coloring book moana  ART_AND_DESIGN     3.9     967
# ...                              ...             ...     ...     ...
# 122646  A+ Gallery - Photos & Videos     PHOTOGRAPHY     4.5  223941
# 122652  A+ Gallery - Photos & Videos     PHOTOGRAPHY     4.5  223941
# 122659  A+ Gallery - Photos & Videos     PHOTOGRAPHY     4.5  223941
# 122660  A+ Gallery - Photos & Videos     PHOTOGRAPHY     4.5  223941
# 122661  A+ Gallery - Photos & Videos     PHOTOGRAPHY     4.5  223941
#
#                       Size     Installs  Type Price Content Rating  \
# 0                      14M     500,000+  Free     0       Everyone
# ...

# %% [markdown]
# ### Cleaning data
# Cleaning data is crucial step before EDA as it will remove the ambigous data that can affect the outcome of EDA.
#
# While cleaning data we will perform following steps:
#
# 1.Remove duplicate rows
#
# 2.Handling missing values.
#
# 3.Convert columns to appropriate datatypes.
#
# 4.Adding important columns
#
# 5.Remove outliers

# %% [markdown]
# ### Removing duplicate rows

# %%
df1[df1.duplicated()].shape
# Out:
# (0, 14)

# %%
# Dropping duplicate values
df1.drop_duplicates(inplace = True)

# %%
df1.shape
# Out:
# (41655, 14)

# %% [markdown]
# ### Handling missing values.

# %%
df1.isnull().sum()
# Out:
# App                   0
# Category              0
# Rating               39
# Reviews               0
# Size                  0
# Installs              0
# Type                  0
# Price                 0
# Content Rating        0
# Genres                0
# Last Updated          0
# Current Ver           0
# Android Ver           0
# Translated_Review     0
#                       0
# dtype: int64

# %%
df1[['Translated_Review','']] = df1[['Translated_Review','Rating']].fillna(0)

# %%
df1['Rating'].fillna(df1['Rating'].mean(), inplace = True)

# %%
#Unique is used to check the data type and total number of that particular column that is 122661
df['App'].unique
# Out:
# <bound method Series.unique of 0                  Coloring book moana
# 1                  Coloring book moana
# 2                  Coloring book moana
# 3                  Coloring book moana
# 4                  Coloring book moana
#                       ...
# 122646    A+ Gallery - Photos & Videos
# 122652    A+ Gallery - Photos & Videos
# 122659    A+ Gallery - Photos & Videos
# 122660    A+ Gallery - Photos & Videos
# 122661    A+ Gallery - Photos & Videos
# Name: App, Length: 41655, dtype: object>

# %%
df1.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating               0
# Reviews              0
# Size                 0
# Installs             0
# Type                 0
# Price                0
# Content Rating       0
# Genres               0
# Last Updated         0
# Current Ver          0
# Android Ver          0
# Translated_Review    0
#                      0
# dtype: int64

# %% [markdown]
# ### Removing outliers

# %%
# Finding the whether it has outliers or not
columns = ['Rating']
n = 1
plt.figure(figsize=(20,15))
plt.style.use('dark_background')
for column in columns:
  plt.subplot(4,4,n)
  n = n+1
  sns.boxplot(df1[column])
  plt.tight_layout()

# %%
#checking the top 5 apps with rating=4.5
df[df['Rating']==4.5].head()
# Out:
#                            App        Category  Rating Reviews Size  Installs  \
# 416  Anime Manga Coloring Book  ART_AND_DESIGN     4.5    5035  11M  100,000+
# 417  Anime Manga Coloring Book  ART_AND_DESIGN     4.5    5035  11M  100,000+
# 418  Anime Manga Coloring Book  ART_AND_DESIGN     4.5    5035  11M  100,000+
# 420  Anime Manga Coloring Book  ART_AND_DESIGN     4.5    5035  11M  100,000+
# 422  Anime Manga Coloring Book  ART_AND_DESIGN     4.5    5035  11M  100,000+
#
#      Type Price Content Rating        Genres   Last Updated Current Ver  \
# 416  Free     0       Everyone  Art & Design  July 19, 2018        2.20
# 417  Free     0       Everyone  Art & Design  July 19, 2018        2.20
# 418  Free     0       Everyone  Art & Design  July 19, 2018        2.20
# 420  Free     0       Everyone  Art & Design  July 19, 2018        2.20
# 422  Free     0       Everyone  Art & Design  July 19, 2018        2.20
#
# ...

# %% [markdown]
# ### corr():
#  It is used to find the pairwise correlation of all columns in the Pandas Dataframe in Python.

# %%
df.corr()
# Out:
#         Rating
# Rating     1.0

# %% [markdown]
# ### Exploratory Analysis and Visualization:
#
# In statistics, exploratory data analysis is an approach to analyzing data sets to summarize their main characteristics, often with visual methods.
#
# A statistical model can be used or not, but primarily EDA is for seeing what the data can tell us beyond the formal modeling or hypothesis testing task.
#
# Data visualization is the graphic representation of data. It involves producing images that communicate relationships among the represented data to viewers of the images.
#
# This communication is achieved through the use of a systematic mapping between graphic marks and data values in the creation of the visualization.
#
# This mapping establishes how data values will be represented visually, determining how and to what extent the property of a graphic mark, such as size or color, will change to reflect changes in the value of a datum.

# %% [markdown]
# ### can we see what are the top categories in the play store, which contains the highest number of apps?

# %%
sns.set_style('darkgrid')
matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['figure.figsize'] = (9, 5)
matplotlib.rcParams['figure.facecolor'] = '#00000000'

# %%
df2=df1.head(2000)

# %%
y = df1['Category'].value_counts()
x = df2['Category'].value_counts().index
xsis = []
ysis = []
for i in range(len(x)):
    xsis.append(x[i])
    ysis.append(y[i])

# %%
plt.style.use("dark_background")
plt.figure(figsize=(10,5))
plt.xlabel("Count")
plt.ylabel("Category")

graph = sns.barplot(x = xsis, y = ysis, palette= "husl")
graph.set_title("Top categories on Google Playstore", fontsize = 25);

# %% [markdown]
# Than analyzing with numbers it is easy for us to tell that which app is downlaoded the most and the least from this as humans can understand something that is picturized that written or in printed form.
#
# From above picture we can tell that COMICS has the very least number of downloads.
#
# So there are all total of 33 categories in the dataset from the above output we can come to the conclusion that in the play store most of the apps are under Family & Game category and least are of Events & Comics Category.

# %% [markdown]
# #### Which category of Apps from the ‘Content Rating’ column is found more on the play store?

# %%
x2 = df['Content Rating'].value_counts().index
y2 = df['Content Rating'].value_counts()

x2sis = []
y2sis = []
for i in range(len(x2)):
    x2sis.append(x2[i])
    y2sis.append(y2[i])

# %%
plt.figure(figsize=(12,10))
plt.bar(x2sis,y2sis,color=['#15244C','#FFFF48','#292734','#EF2920','#CD202D','#ECC5F2'], alpha=0.8);
plt.title('Content Rating',size = 20);
plt.ylabel('Apps(Count)');
plt.xlabel('Content Rating');

# %% [markdown]
# From above bar diagram , we can see the total app counts and how the content ratings are in different age groups.From the above plot, we can see that the Everyone category has the highest number of apps and adult contents are with lesser rating compared to others.

# %%
df['Size'] = df.Size.apply(lambda x: x.replace('M', 'e+6'))# For converting the M to Mega

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 41655 entries, 0 to 122661
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   App                41655 non-null  object
#  1   Category           41655 non-null  object
#  2   Rating             41616 non-null  float64
#  3   Reviews            41655 non-null  object
#  4   Size               41655 non-null  object
#  5   Installs           41655 non-null  object
#  6   Type               41655 non-null  object
#  7   Price              41655 non-null  object
#  8   Content Rating     41655 non-null  object
#  9   Genres             41655 non-null  object
#  10  Last Updated       41655 non-null  object
#  11  Current Ver        41655 non-null  object
#  12  Android Ver        41655 non-null  object
#  13  Translated_Review  40414 non-null  object
# dtypes: float64(1), object(13)
# memory usage: 4.8+ MB

# %% [markdown]
# #### It will be a better idea to drop the Rows of the column Size having Nanvalues because it will be not an efficient idea to replace those values with mean or mode since the size of some apps would be too large and some of them too small.

# %% [markdown]
# ### What Is Skewness?
#
# Skewness refers to a distortion or asymmetry that deviates from the symmetrical bell curve, or normal distribution, in a set of data.
#
# ### What is Kurtosis?
#
# It is a measure of whether the data are heavy-tailed or light-tailed relative to a normal distribution.
#
# ### To check skewness and kurtosis
# We use the below function

# %%
print("Skewness: %f" %df['Rating'].skew())
print("Kurtosis: %f" %df['Rating'].kurt())
# Out:
# Skewness: -1.396274
# Kurtosis: 3.711531

# %% [markdown]
# ### Let’s have a look at the distribution of the ratings of the data frame.

# %%
plt.figure(figsize=(15,9))
plt.xlabel("Rating")
plt.ylabel("Frequency")
graph = sns.kdeplot(df.Rating, color="Blue", shade = True)
plt.title('Distribution of Rating');

# %% [markdown]
# ### From the above graph, we can come to the conclusion that most of the apps in the google play store are rated between 3.5 to 4.8.

# %% [markdown]
# ### Let’s plot a visualization graph to view what portion of the apps in the play store are paid and free.

# %%
plt.figure(figsize=(10,10))
labels = df['Type'].value_counts(sort = True).index
sizes = df['Type'].value_counts(sort = True)
colors = ["blue","lightgreen"]
explode = (0.2,0)
plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=0)
plt.title('Percent of Free Vs Paid Apps in store',size = 20)
plt.show()

# %% [markdown]
# ### From the above graph, we can see that 92%(Approx.) of apps in the google play store are free and 8%(Approx.) are paid.

# %% [markdown]
# ### Which category App’s have the most number of installs?

# %% [markdown]
# ### *To answer this question i have created a separate data frame out of our df data frame which will contain a grouped value by Category and Installs .

# %%
df2=df.copy()

# %%
df3=df2.head(1500)

# %%
highest_Installs_df = df3.groupby('Category')[['Installs']].sum().sort_values(by='Installs', ascending=False)

# %%
x2sis = []
y2sis = []

for i in range(len(highest_Installs_df)):
    x2sis.append(highest_Installs_df.Installs[i])
    y2sis.append(highest_Installs_df.index[i])

plt.figure(figsize=(12,5))

plt.xlabel("Category")
plt.ylabel("Installs")
graph = sns.barplot(x = y2sis, y = x2sis, alpha =0.9, palette= "viridis")
graph.set_title("Installs", fontsize = 16);0

# %% [markdown]
# ### From the above visualization, it can be interpreted that the top categories with the highest installs are Game, Family, Communication, News & Magazines, & Tools.

# %% [markdown]
# ### What are the Top 10 installed apps in any category??

# %% [markdown]
# #### So let’s test it by passing Sports category to the above-defined function.

# %% [markdown]
# ### Which are the top 10 expensive Apps in the play store?

# %%
top10PaidApps =df[df['Type'] == 'Paid'].sort_values(by='Price', ascending=False).head(100)

# %%
top10PaidApps_df = top10PaidApps[['App', 'Installs']]

# %%
plt.figure(figsize=(10,5));
plt.pie(top10PaidApps_df.Installs, explode=None, labels=top10PaidApps_df.App, autopct='%1.1f%%', startangle=0);
plt.title('Top Expensive Apps Distribution',size = 20);
plt.legend(top10PaidApps_df.App, 
           loc="lower right",
           title="Apps",
           fontsize = "xx-small"
          );

# %% [markdown]
# ### Which are the Apps with the highest number of reviews?

# %%
Apps_with_Highest_rev =df.sort_values(by='Reviews', ascending=False).head(20)

# %%
Apps_with_Highest_rev
# Out:
#                App          Category  Rating Reviews   Size  Installs  Type  \
# 103905  DreamTrips  TRAVEL_AND_LOCAL     4.7    9971  22e+6    500000  Free
# 103903  DreamTrips  TRAVEL_AND_LOCAL     4.7    9971  22e+6    500000  Free
# 103894  DreamTrips  TRAVEL_AND_LOCAL     4.7    9971  22e+6    500000  Free
# 103896  DreamTrips  TRAVEL_AND_LOCAL     4.7    9971  22e+6    500000  Free
# 103897  DreamTrips  TRAVEL_AND_LOCAL     4.7    9971  22e+6    500000  Free
# 103898  DreamTrips  TRAVEL_AND_LOCAL     4.7    9971  22e+6    500000  Free
# 103899  DreamTrips  TRAVEL_AND_LOCAL     4.7    9971  22e+6    500000  Free
# 103900  DreamTrips  TRAVEL_AND_LOCAL     4.7    9971  22e+6    500000  Free
# 103901  DreamTrips  TRAVEL_AND_LOCAL     4.7    9971  22e+6    500000  Free
# 103902  DreamTrips  TRAVEL_AND_LOCAL     4.7    9971  22e+6    500000  Free
# 103904  DreamTrips  TRAVEL_AND_LOCAL     4.7    9971  22e+6    500000  Free
# ...

# %% [markdown]
# ### *From the above data frame we can interpret,and come to the conclusion that the DreamTrips has the highest number of reviews on google play store.

# %% [markdown]
# ### What are the count of Apps in different genres?

# %%
topAppsinGenres = df['Genres'].value_counts().head(10)

# %%
x3sis = []
y3sis = []

for i in range(len(topAppsinGenres)):
    x3sis.append(topAppsinGenres.index[i])
    y3sis.append(topAppsinGenres[i])

# %%
plt.figure(figsize=(15,9))
plt.ylabel('Genres(App Count)')
plt.xlabel('Genres')
graph = sns.barplot(x=x3sis,y=y3sis,palette="deep")
graph.set_xticklabels(graph.get_xticklabels(), rotation=90, fontsize=12)
graph.set_title("Top Genres in the Playstore", fontsize = 20);

# %% [markdown]
# ### From the above visualization,we can see that the Highest Number of Apps found are Action,Sports ,Health and follows.
